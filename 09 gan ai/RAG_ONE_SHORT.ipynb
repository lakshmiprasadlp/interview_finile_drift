# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ARAG

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# C RAG

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # self Rag

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # COPALI RAG
